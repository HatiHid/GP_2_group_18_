# %% [markdown]
# # **04_data_api_processing_merge.ipynb**
#
# В этом ноутбуке данные были обработаны и объединены с основной таблицей объектов, собранной при парсинге Move.ru.

# %%
import requests
import json
import time
from typing import List, Dict, Any
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import numpy as np

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
dff = pd.read_csv('итогAPI.csv')

# %% [markdown]
# РАБОТА С ПРОПУСКАМИ

# %%
dff
# Out:
#                район           тип  \
# 0      Академический  бизнес-центр
# 1      Академический  бизнес-центр
# 2      Академический  бизнес-центр
# 3      Академический  бизнес-центр
# 4      Академический  бизнес-центр
# ...              ...           ...
# 21213        Ясенево         школа
# 21214        Ясенево         школа
# 21215        Ясенево         школа
# 21216        Ясенево         школа
# 21217        Ясенево         школа
#
#                                                название  \
# 0                             Ферро-Плаза, бизнес-центр
# 1                          Микроэкономика, бизнес-центр
# 2                                   iCube, бизнес-центр
# 3                           Академический, бизнес-центр
# 4                                   Бизнес-Недвижимость
# ...                                                 ...
# 21213   Школа №1103, школа им. Героя РФ А.В. Соломатина
# 21214                                       Школа №2103
# 21215  Школа им. Н.М. Карамзина, Остафьевский корпус №9
# 21216                             London Express, школа
# 21217                                       Школа №1212
#
#                                   адрес     широта    долгота       рейтинг  \
# 0           улица Кржижановского, 14 к3  55.679541  37.566590           3.7
# 1      Большая Черёмушкинская улица, 34  55.679174  37.583232           3.7
# 2              Нахимовский проспект, 58  55.683738  37.554129           4.7
# 3      60-летия Октября проспект, 9 ст2  55.698817  37.580293  нет рейтинга
# 4          Новочерёмушкинская улица, 25  55.680746  37.578958           4.9
# ...                                 ...        ...        ...           ...
# 21213          Литовский бульвар, 42 к2  55.608020  37.541734           4.9
# 21214          Голубинская улица, 13 к2  55.603158  37.517547  нет рейтинга
# 21215            проезд Карамзина, 9 к2  55.591577  37.540696  нет рейтинга
# 21216              Соловьиный проезд, 1  55.619451  37.543880             5
# 21217             Вильнюсская улица, 14  55.598321  37.517026             5
#
#        количество_отзывов  количество_оценок
# 0                       8                 30
# 1                       5                 36
# 2                      11                 36
# 3                       0                 27
# 4                       2                 13
# ...                   ...                ...
# 21213                   1                  4
# 21214                   0                  2
# 21215                   0                  0
# 21216                   3                  5
# 21217                   2                  7
#
# [21218 rows x 9 columns]

# %%
dff.isna().sum()
# Out:
# район                   0
# тип                     0
# название                0
# адрес                 190
# широта                  0
# долгота                 0
# рейтинг                 0
# количество_отзывов      0
# количество_оценок       0
# dtype: int64

# %% [markdown]
# Видим, что пропуски есть только в признаке адрес. Это связано с тем, что на сайте 2гис для некоторых объектов не указан адрес. У таких объектов указан только район и город.

# %%
dff[dff['адрес'].isna()]
# Out:
#               район             тип  \
# 239    Алексеевский            кафе
# 562           Арбат           музей
# 748        Аэропорт            парк
# 1151      Басманный            парк
# 1623       Бибирево            кафе
# ...             ...             ...
# 20865      Якиманка            парк
# 20866      Якиманка            парк
# 20867      Якиманка            парк
# 21159       Ясенево            парк
# 21183       Ясенево  торговый центр
#
#                                                 название адрес     широта  \
# 239          Церковный дворик, кафе фермерской продукции   NaN  55.808282
# 562             Музей счастливого детства, книжная лавка   NaN  55.752312
# 748                                      Петровский парк   NaN  55.793866
# 1151                                         Горка, парк   NaN  55.756114
# 1623                   Piazza del cafе, кофейный автомат   NaN  55.883405
# ...                                                  ...   ...        ...
# 20865  Центральный парк культуры и отдыха им. М. Горь...   NaN  55.728201
# 20866                                Нескучный сад, парк   NaN  55.717043
# 20867                              Музеон, парк искусств   NaN  55.736473
# 21159     Принц парк отель, Парковка ГК Принц парк отель   NaN  55.616813
# 21183                 Парковка, торговый центр ТвинПлаза   NaN  55.617805
#
#          долгота       рейтинг  количество_отзывов  количество_оценок
# 239    37.654088  нет рейтинга                   0                  1
# 562    37.584955  нет рейтинга                   0                  4
# 748    37.557141           4.7                  99                669
# 1151   37.636096           4.2                   1                  3
# 1623   37.604799  нет рейтинга                   0                  0
# ...          ...           ...                 ...                ...
# 20865  37.600249           4.9                1891               7808
# 20866  37.586490           4.8                 327               1377
# 20867  37.608145           4.9                 477               2132
# 21159  37.511657  нет рейтинга                   0                  0
# 21183  37.506473  нет рейтинга                   0                  1
#
# [190 rows x 9 columns]

# %%
dff['рейтинг'].value_counts()
# Out:
# рейтинг
# нет рейтинга    5256
# 5               3655
# 4.7             1475
# 4.8             1444
# 4.6             1132
# 4.9             1103
# 4.5              984
# 4.4              654
# 4.3              564
# 4.2              465
# 4                449
# 4.1              377
# 3.9              297
# 3.7              293
# 3                283
# 3.8              263
# 3.5              210
# 1                197
# 3.6              195
# 3.4              183
# 3.2              178
# 3.3              175
# 3.1              175
# 2.3              124
# 2.7              110
# 2.5              110
# 2.8              101
# 1.4               93
# 2.9               92
# 2.4               80
# 1.7               76
# 2.6               76
# 2.1               74
# 2                 62
# 1.9               50
# 2.2               37
# 1.8               31
# 1.5               30
# 1.2               23
# 1.6               13
# 0                 12
# 1.3                9
# 1.1                8
# Name: count, dtype: int64

# %% [markdown]
# Однако еще мы можем понять, что пропуски есть и в признаке 'рейтинг', когда рейтинг на сайте 2гис отсутствует. У нас в признаке это помечается как "нет рейтинга", поэтому в пропуски это не суммируется, так как значение в признаке присутствует. Тогда заменим все значения "нет рейтинга" на NaN.

# %%
import re

# %%
dff.loc[dff['рейтинг'].str.match(r'^нет рейтинга$', na=False), 'рейтинг'] = np.nan

# %%
dff
# Out:
#                район           тип  \
# 0      Академический  бизнес-центр
# 1      Академический  бизнес-центр
# 2      Академический  бизнес-центр
# 3      Академический  бизнес-центр
# 4      Академический  бизнес-центр
# ...              ...           ...
# 21213        Ясенево         школа
# 21214        Ясенево         школа
# 21215        Ясенево         школа
# 21216        Ясенево         школа
# 21217        Ясенево         школа
#
#                                                название  \
# 0                             Ферро-Плаза, бизнес-центр
# 1                          Микроэкономика, бизнес-центр
# 2                                   iCube, бизнес-центр
# 3                           Академический, бизнес-центр
# 4                                   Бизнес-Недвижимость
# ...                                                 ...
# 21213   Школа №1103, школа им. Героя РФ А.В. Соломатина
# 21214                                       Школа №2103
# 21215  Школа им. Н.М. Карамзина, Остафьевский корпус №9
# 21216                             London Express, школа
# 21217                                       Школа №1212
#
#                                   адрес     широта    долгота рейтинг  \
# 0           улица Кржижановского, 14 к3  55.679541  37.566590     3.7
# 1      Большая Черёмушкинская улица, 34  55.679174  37.583232     3.7
# 2              Нахимовский проспект, 58  55.683738  37.554129     4.7
# 3      60-летия Октября проспект, 9 ст2  55.698817  37.580293     NaN
# 4          Новочерёмушкинская улица, 25  55.680746  37.578958     4.9
# ...                                 ...        ...        ...     ...
# 21213          Литовский бульвар, 42 к2  55.608020  37.541734     4.9
# 21214          Голубинская улица, 13 к2  55.603158  37.517547     NaN
# 21215            проезд Карамзина, 9 к2  55.591577  37.540696     NaN
# 21216              Соловьиный проезд, 1  55.619451  37.543880       5
# 21217             Вильнюсская улица, 14  55.598321  37.517026       5
#
#        количество_отзывов  количество_оценок
# 0                       8                 30
# 1                       5                 36
# 2                      11                 36
# 3                       0                 27
# 4                       2                 13
# ...                   ...                ...
# 21213                   1                  4
# 21214                   0                  2
# 21215                   0                  0
# 21216                   3                  5
# 21217                   2                  7
#
# [21218 rows x 9 columns]

# %%
dff.isna().sum()
# Out:
# район                    0
# тип                      0
# название                 0
# адрес                  190
# широта                   0
# долгота                  0
# рейтинг               5256
# количество_отзывов       0
# количество_оценок        0
# dtype: int64

# %% [markdown]
# Таким образом, в датасете после апи-парсинга в признаке 'рейтинг' 190 пропусков из 21218, а в признаке 'рейтинг' - 5256 из 2128.

# %%
dff[(dff['рейтинг'].isna()) & (dff['количество_оценок']!=0)]
# Out:
#                район           тип                              название  \
# 3      Академический  бизнес-центр           Академический, бизнес-центр
# 5      Академический  бизнес-центр         Принципал Плаза, бизнес-центр
# 9      Академический  бизнес-центр                          Бизнес-центр
# 10     Академический  бизнес-центр                  Карьер, бизнес-центр
# 11     Академический  бизнес-центр          Plaza Kedrova, офисный центр
# ...              ...           ...                                   ...
# 21204        Ясенево         школа                Школа №1561, корпус №4
# 21206        Ясенево         школа                           Школа №2103
# 21208        Ясенево         школа  Ясенево, школа №1694 им. П.М. Фитина
# 21209        Ясенево         школа                           Школа №1212
# 21214        Ясенево         школа                           Школа №2103
#
#                                   адрес     широта    долгота рейтинг  \
# 3      60-летия Октября проспект, 9 ст2  55.698817  37.580293     NaN
# 5        60-летия Октября проспект, 10а  55.692721  37.574555     NaN
# 9            улица Ивана Бабушкина, 16а  55.684838  37.560352     NaN
# 10                 улица Карьер, 2а ст2  55.694974  37.591161     NaN
# 11                 улица Кедрова, 13 к2  55.684730  37.572909     NaN
# ...                                 ...        ...        ...     ...
# 21204    Новоясеневский проспект, 38 к2  55.602029  37.543707     NaN
# 21206           Голубинская улица, 5 к4  55.604795  37.517975     NaN
# 21208           Соловьиный проезд, 4 к2  55.614998  37.547954     NaN
# 21209    Новоясеневский проспект, 24 к3  55.603855  37.528777     NaN
# 21214          Голубинская улица, 13 к2  55.603158  37.517547     NaN
#
#        количество_отзывов  количество_оценок
# 3                       0                 27
# 5                       0                 38
# 9                       0                  1
# 10                      0                  1
# 11                      0                  1
# ...                   ...                ...
# 21204                   0                  2
# 21206                   0                  4
# 21208                   0                  2
# 21209                   0                  1
# 21214                   0                  2
#
# [2499 rows x 9 columns]

# %%
dff[dff['рейтинг'].isna() & dff['количество_отзывов']!=0]
# Out:
# Empty DataFrame
# Columns: [район, тип, название, адрес, широта, долгота, рейтинг, количество_отзывов, количество_оценок]
# Index: []

# %%
dff[dff['рейтинг'].notna()]['количество_отзывов'].value_counts()
# Out:
# количество_отзывов
# 1       2409
# 2       1499
# 3        997
# 4        723
# 5        516
#         ...
# 1199       1
# 671        1
# 509        1
# 1602       1
# 311        1
# Name: count, Length: 480, dtype: int64

# %% [markdown]
# Видно, что у всех объектов, у которых есть рейтинг, число отзывов больше или равно 1.

# %%
dff[dff['рейтинг'].isna()]['количество_отзывов'].value_counts()
# Out:
# количество_отзывов
# 0    5256
# Name: count, dtype: int64

# %% [markdown]
# А у всех объетков, у которых отсутствует рейтинг, число отзывов равно 0.

# %% [markdown]
# Таким образом, пропуски в признаке 'рейтинг' появились из-за того, что 2ГИС не показывает рейтинг, пока не наберется минимальное количество отзывов - хотя бы 1 отзыв.

# %% [markdown]
# + Новые организации, которые недавно добавились в каталог и не получили отзывов
# + Компании, которые запретили отзывы
# + Непопулярные и малоизвестные организации без отзывов

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# Обработка датасета для склеивания с веб-скрапингом.

# %%
res = pd.read_csv('количество.csv')

# %%
res
# Out:
#              район  бизнес-центр  детский сад  кафе  магазин  музей  парк  \
# 0    Академический            13           30    38       50      8     1
# 1     Алексеевский            17           21    44       50      2     0
# 2     Алтуфьевский             7           10     5       32      1     1
# 3            Арбат            27           11    50       50     27     1
# 4         Аэропорт            21           32    50       50      7    12
# ..             ...           ...          ...   ...      ...    ...   ...
# 127   Южное Тушино            11           19    24       50      0     2
# 128   Южнопортовый            18           19    50       50      1     8
# 129       Якиманка            26            9    50       47     19     3
# 130    Ярославский             4           23    22       50      0     1
# 131        Ясенево             4           41    42       50      1     5
#
#      поликлиника  торговый центр  школа
# 0              9               2     19
# 1              9               3     16
# 2              4               2      6
# 3              5               8      9
# 4              9               7     15
# ..           ...             ...    ...
# 127            3               4     22
# 128           10               9     15
# 129            6               4     13
# 130            4               8     14
# 131           13              11     34
#
# [132 rows x 10 columns]

# %%
res.isna().sum()
# Out:
# район             0
# бизнес-центр      0
# детский сад       0
# кафе              0
# магазин           0
# музей             0
# парк              0
# поликлиника       0
# торговый центр    0
# школа             0
# dtype: int64

# %% [markdown]
# В данном датасете нет пропусков, что логично, так как при группировке и сборе этого датасета (по таблице итогAPI) для каждого района считалось число имеющихся в нем объектов разного типа, и поэтому для всех типов в каждом регионе есть значение количества этого объекта в регионе.

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# Таблица с информацией по районам Москвы из викепедии. Информация в таблице из Росстата, а у 8 из 132 районов нет информации, так как они были созданы только в 2024 году и на Росстате нет информации о них.

# %%
regions = pd.read_excel('wikip.xlsx')

# %%
regions
# Out:
#     Название района Административный округ Площадь, км²  \
# 0     Академический                   ЮЗАО         5.83
# 1      Алексеевский                   СВАО         5.29
# 2      Алтуфьевский                   СВАО         3.25
# 3             Арбат                    ЦАО         2.11
# 4          Аэропорт                    САО         4.58
# ..              ...                    ...          ...
# 127    Южное Тушино                   СЗАО         7.94
# 128    Южнопортовый                   ЮВАО         4.53
# 129        Якиманка                    ЦАО          4.8
# 130     Ярославский                   СВАО         7.99
# 131         Ясенево                   ЮЗАО        25.37
#
#     Население на 2024, чел.  Плотность населения на 2024, чел./км²  \
# 0                    114 228                              19593.14
# 1                     77 681                               14684.5
# 2                     55 741                              17151.08
# 3                     36 246                               17178.2
# 4                     81 833                              17867.47
# ..                       ...                                   ...
# 127                  112 628                              14184.89
# 128                   73 112                              16139.51
# 129                   27 022                               5629.58
# 130                   98 861                              12373.09
# 131                  176 505                               6957.23
#
#     Площадь жилого фонда (01.01.2010), тыс. м²  \
# 0                                         2467
# 1                                       1607.9
# 2                                        839.3
# 3                                          731
# 4                                       1939.7
# ..                                         ...
# 127                                     1714.9
# 128                                       1449
# 129                                      788.7
# 130                                     1404.5
# 131                                     2969.3
#
#     Жилплощадь на человека (01.01.2010), м²/чел.
# 0                                           22.7
# 1                                           20.5
# 2                                           15.5
# 3                                             26
# 4                                           25.9
# ..                                           ...
# 127                                         16.9
# 128                                         20.6
# 129                                         29.8
# 130                                         15.3
# 131                                         16.4
#
# [132 rows x 7 columns]

# %%
regions[regions['Название района']=='Бекасово']
# Out:
#   Название района Административный округ Площадь, км²  \
# 8        Бекасово                    ТАО            —
#
#   Население на 2024, чел.  Плотность населения на 2024, чел./км²  \
# 8               Неизвестно                            Неизвестно
#
#   Площадь жилого фонда (01.01.2010), тыс. м²  \
# 8                                 Неизвестно
#
#   Жилплощадь на человека (01.01.2010), м²/чел.
# 8                                   Неизвестно

# %%
import re

# %%
regions['Площадь, км²'] = regions['Площадь, км²'].replace(r'^—$', np.nan, regex=True)

# %%
regions = regions.replace(r'^Неизвестно$', np.nan, regex=True)
# Out:
# /tmp/ipython-input-4117153067.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   regions = regions.replace('Неизвестно', np.nan)

# %%
regions.isna().sum()
# Out:
# Название района                                 0
# Административный округ                          0
# Площадь, км²                                    8
# Население на 2024, чел.                         8
# Плотность населения на 2024, чел./км²           8
# Площадь жилого фонда (01.01.2010), тыс. м²      7
# Жилплощадь на человека (01.01.2010), м²/чел.    7
# dtype: int64

# %% [markdown]
# Заполним информацией с другого сайта (энциклопедия).

# %% [markdown]
# Таблица с заполненными пропусками будет в файле wikipWITHOUT.xlsx

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# Соединим таблицы, полученные в ходе веб-скрапинга и апи-парсинга.

# %%
pars = pd.read_csv('parsingMOVEsplit.csv')

# %%
pars['район'] = pars['district'].str.replace('район', '', regex=False)
# Убираем лишние пробелы, которые могли образоваться
pars['район'] = pars['район'].str.strip()
del pars['district']

# %%
pars
# Out:
#        price_millions                      complex_name     developer  \
# 0              629.32        Клубный дом «Хамовники 12»         COLDY
# 1               25.18          Квартал «Серебряный бор»     StMichael
# 2               20.27  Апарт-комплекс «Движение.Тушино»      ГК «ФСК»
# 3               12.61           ЖК «BeLuck Коломенское»  ГК «Гранель»
# 4               14.11                           ЖК VEER      MR Group
# ...               ...                               ...           ...
# 10524           21.76                        ЖК Moments         FORMA
# 10525           17.55                 ЖК «Руставели 14»           ПИК
# 10526           20.08                               NaN           NaN
# 10527           22.05                        ЖК Moments         FORMA
# 10528           28.66                        ЖК Moments         FORMA
#
#        housing_class  floor  total_floors  rooms  total_area  living_area  \
# 0         Элит класс    2.0          14.0    4.0      202.70       140.00
# 1       Бизнес класс    7.0          25.0    NaN       24.07        14.56
# 2      Комфорт класс   19.0          22.0    2.0       52.80        26.40
# 3      Комфорт класс   16.0          32.0    NaN       32.36        23.56
# 4       Бизнес класс    6.0          22.0    NaN       22.20        14.35
# ...              ...    ...           ...    ...         ...          ...
# 10524   Бизнес класс    5.0          30.0    1.0       44.50        14.40
# 10525  Комфорт класс    3.0          21.0    1.0       31.80         9.40
# 10526            NaN   11.0          43.0    NaN       30.10        13.10
# 10527   Бизнес класс   24.0          34.0    1.0       43.40        14.80
# 10528   Бизнес класс   14.0          34.0    2.0       65.90        26.20
#
#        kitchen_area  ...                                         metro_data  \
# 0              20.0  ...  [{'name': 'Киевская', 'distance_m': 1000}, {'n...
# 1               NaN  ...  [{'name': 'Щукинская', 'distance_m': 3000}, {'...
# 2              11.5  ...  [{'name': 'Спартак', 'distance_m': 682}, {'nam...
# 3               NaN  ...  [{'name': 'Нагатинская', 'distance_m': 1000}, ...
# 4               NaN  ...  [{'name': 'Давыдково', 'distance_m': 2000}, {'...
# ...             ...  ...                                                ...
# 10524          21.4  ...  [{'name': 'Войковская', 'distance_m': 2000}, {...
# 10525          15.0  ...  [{'name': 'Бутырская', 'distance_m': 524}, {'n...
# 10526           NaN  ...  [{'name': 'Крылатское', 'distance_m': 3000}, {...
# 10527          20.8  ...  [{'name': 'Войковская', 'distance_m': 2000}, {...
# 10528          22.1  ...  [{'name': 'Войковская', 'distance_m': 2000}, {...
#
#                                              metro_names nearest_metro  \
# 0      ['Киевская', 'Фрунзенская', 'Парк культуры', '...      Киевская
# 1      ['Щукинская', 'Октябрьское поле', 'Народное Оп...     Щукинская
# 2      ['Спартак', 'Тушинская', 'Щукинская', 'Строгин...       Спартак
# 3      ['Нагатинская', 'Нагорная', 'Коломенская', 'На...   Нагатинская
# 4      ['Давыдково', 'Аминьевская', 'Кунцевская', 'Сл...     Давыдково
# ...                                                  ...           ...
# 10524  ['Войковская', 'Щукинская', 'Октябрьское поле'...    Войковская
# 10525  ['Бутырская', 'Фонвизинская', 'Дмитровская', '...     Бутырская
# 10526  ['Крылатское', 'Молодежная', 'Народное Ополчен...    Крылатское
# 10527  ['Войковская', 'Щукинская', 'Октябрьское поле'...    Войковская
# 10528  ['Войковская', 'Щукинская', 'Октябрьское поле'...    Войковская
#
#       nearest_metro_distance  views  \
# 0                     1000.0  320.0
# 1                     3000.0   61.0
# 2                      682.0   64.0
# 3                     1000.0   64.0
# 4                     2000.0   56.0
# ...                      ...    ...
# 10524                 2000.0   19.0
# 10525                  524.0    5.0
# 10526                 3000.0   28.0
# 10527                 2000.0    6.0
# 10528                 2000.0   17.0
#
#                                                      url    city okrug  \
# 0      https://move.ru/objects/moskva_pereulok_trujen...  Москва   ЦАО
# 1      https://move.ru/objects/prodaetsya_studiya_plo...  Москва  СЗАО
# 2      https://move.ru/objects/prodaetsya_2-komnatnay...  Москва  СЗАО
# 3      https://move.ru/objects/prodaetsya_studiya_plo...  Москва   ЮАО
# 4      https://move.ru/objects/prodaetsya_studiya_plo...  Москва   ЗАО
# ...                                                  ...     ...   ...
# 10524  https://move.ru/objects/prodaetsya_1-komnatnay...  Москва  СЗАО
# 10525  https://move.ru/objects/prodaetsya_1-komnatnay...  Москва  СВАО
# 10526  https://move.ru/objects/prodaetsya_studiya_plo...  Москва   ЗАО
# 10527  https://move.ru/objects/prodaetsya_1-komnatnay...  Москва  СЗАО
# 10528  https://move.ru/objects/prodaetsya_2-komnatnay...  Москва  СЗАО
#
#                                       other                 район
# 0                   пер. 1-й Тружеников, 12             Хамовники
# 1                          ул. Берзарина, 3                Щукино
# 2                    Волоколамское шоссе, 4  Покровское-Стрешнево
# 3                      Каширское шоссе, 1.1    Нагатино-Садовники
# 4                  ул. Багрицкого, Indigo-4             Можайский
# ...                                     ...                   ...
# 10524  1-й Красногорский проезд, Корпус 2.1                Щукино
# 10525                            Корпус 3.7             Бутырский
# 10526                    ул. Крылатская, 33            Крылатское
# 10527  1-й Красногорский проезд, Корпус 2.2                Щукино
# 10528  1-й Красногорский проезд, Корпус 2.2                Щукино
#
# [10529 rows x 21 columns]

# %%
merged = pars.merge(res, how='left', on = 'район')

# %%
merged.to_csv('merged.csv')

# %%
merged
# Out:
#        price_millions                      complex_name     developer  \
# 0              629.32        Клубный дом «Хамовники 12»         COLDY
# 1               25.18          Квартал «Серебряный бор»     StMichael
# 2               20.27  Апарт-комплекс «Движение.Тушино»      ГК «ФСК»
# 3               12.61           ЖК «BeLuck Коломенское»  ГК «Гранель»
# 4               14.11                           ЖК VEER      MR Group
# ...               ...                               ...           ...
# 10524           21.76                        ЖК Moments         FORMA
# 10525           17.55                 ЖК «Руставели 14»           ПИК
# 10526           20.08                               NaN           NaN
# 10527           22.05                        ЖК Moments         FORMA
# 10528           28.66                        ЖК Moments         FORMA
#
#        housing_class  floor  total_floors  rooms  total_area  living_area  \
# 0         Элит класс    2.0          14.0    4.0      202.70       140.00
# 1       Бизнес класс    7.0          25.0    NaN       24.07        14.56
# 2      Комфорт класс   19.0          22.0    2.0       52.80        26.40
# 3      Комфорт класс   16.0          32.0    NaN       32.36        23.56
# 4       Бизнес класс    6.0          22.0    NaN       22.20        14.35
# ...              ...    ...           ...    ...         ...          ...
# 10524   Бизнес класс    5.0          30.0    1.0       44.50        14.40
# 10525  Комфорт класс    3.0          21.0    1.0       31.80         9.40
# 10526            NaN   11.0          43.0    NaN       30.10        13.10
# 10527   Бизнес класс   24.0          34.0    1.0       43.40        14.80
# 10528   Бизнес класс   14.0          34.0    2.0       65.90        26.20
#
#        kitchen_area  ...                 район бизнес-центр детский сад кафе  \
# 0              20.0  ...             Хамовники           45          43   50
# 1               NaN  ...                Щукино            7          35   43
# 2              11.5  ...  Покровское-Стрешнево           12          18   42
# 3               NaN  ...    Нагатино-Садовники           16          23   50
# 4               NaN  ...             Можайский           27          42   44
# ...             ...  ...                   ...          ...         ...  ...
# 10524          21.4  ...                Щукино            7          35   43
# 10525          15.0  ...             Бутырский           21          17   50
# 10526           NaN  ...            Крылатское            6          18   24
# 10527          20.8  ...                Щукино            7          35   43
# 10528          22.1  ...                Щукино            7          35   43
#
#        магазин  музей парк поликлиника торговый центр школа
# 0           50     39    1          20              1    36
# 1           50      3    0          15              8    24
# 2           50      3    4           9              7    14
# 3           50      1    2          10              6    27
# 4           50      0   23           6              8    22
# ...        ...    ...  ...         ...            ...   ...
# 10524       50      3    0          15              8    24
# 10525       50      2    7           4             10    11
# 10526       50      2    3          13             11    14
# 10527       50      3    0          15              8    24
# 10528       50      3    0          15              8    24
#
# [10529 rows x 30 columns]

# %% [markdown]
# Теперь присоединим данные про районы.

# %%
wik = pd.read_excel('wikipWITHOUT.xlsx')

# %%
merged = merged.merge(wik, how = 'left', on = 'район')

# %% [markdown]
# Целевой переменной нашего проекта будет являтся цена квадратного метра. Добавим этот признак.

# %%
merged['цена_за_квМ'] = merged['price_millions'] / merged['total_area']

# %%
merged.to_csv('merge.csv')

# %% [markdown]
# Теперь добавим признаки, которые будут показывать средний рейтинг по определенному объекту в определенном районе.

# %%
dff = dff.dropna(subset=['рейтинг']) #удаляем строки с пропусками в столбце рейтинг, чтобыдальше они не мешали при расчетах

# %%
dff['рейтинг'] = dff['рейтинг'].astype(float)

# %%
gr = dff.groupby(['район', 'тип'])['рейтинг'].mean().unstack()

# %%
gr.columns = [f'средний_рейтинг_{str(col).lower()}_в_районе' for col in gr.columns]

# %%
gr
# Out:
#                средний_рейтинг_бизнес-центр_в_районе  \
# район
# Академический                               4.542857
# Алексеевский                                4.200000
# Алтуфьевский                                4.880000
# Арбат                                       4.716667
# Аэропорт                                    4.668750
# ...                                              ...
# Южное Тушино                                4.550000
# Южнопортовый                                4.250000
# Якиманка                                    4.678571
# Ярославский                                 4.700000
# Ясенево                                     4.800000
#
#                средний_рейтинг_детский сад_в_районе  \
# район
# Академический                              4.314286
# Алексеевский                               4.500000
# Алтуфьевский                               4.500000
# Арбат                                      5.000000
# Аэропорт                                   4.871429
# ...                                             ...
# Южное Тушино                               4.320000
# Южнопортовый                               4.583333
# Якиманка                                   5.000000
# Ярославский                                4.611111
# Ясенево                                    4.661538
#
#                средний_рейтинг_кафе_в_районе  \
# район
# Академический                       4.244444
# Алексеевский                        4.282051
# Алтуфьевский                        3.900000
# Арбат                               4.151111
# Аэропорт                            4.280952
# ...                                      ...
# Южное Тушино                        3.955000
# Южнопортовый                        3.922500
# Якиманка                            4.197959
# Ярославский                         3.995000
# Ясенево                             3.836364
#
#                средний_рейтинг_магазин_в_районе  \
# район
# Академический                          4.177083
# Алексеевский                           4.522000
# Алтуфьевский                           4.348000
# Арбат                                  4.314286
# Аэропорт                               4.329545
# ...                                         ...
# Южное Тушино                           4.368889
# Южнопортовый                           4.457447
# Якиманка                               4.408333
# Ярославский                            4.465909
# Ясенево                                4.546809
#
#                средний_рейтинг_музей_в_районе  средний_рейтинг_парк_в_районе  \
# район
# Академический                        4.442857                       4.000000
# Алексеевский                         4.950000                            NaN
# Алтуфьевский                              NaN                       3.800000
# Арбат                                4.760000                       4.900000
# Аэропорт                             4.883333                       3.960000
# ...                                       ...                            ...
# Южное Тушино                              NaN                            NaN
# Южнопортовый                         5.000000                       4.600000
# Якиманка                             4.582353                       4.866667
# Ярославский                               NaN                       4.000000
# Ясенево                              4.800000                       4.625000
#
#                средний_рейтинг_поликлиника_в_районе  \
# район
# Академический                              3.475000
# Алексеевский                               3.166667
# Алтуфьевский                               4.466667
# Арбат                                      4.733333
# Аэропорт                                   3.642857
# ...                                             ...
# Южное Тушино                               3.850000
# Южнопортовый                               4.220000
# Якиманка                                   4.400000
# Ярославский                                2.966667
# Ясенево                                    3.842857
#
#                средний_рейтинг_торговый центр_в_районе  \
# район
# Академический                                 4.350000
# Алексеевский                                  4.800000
# Алтуфьевский                                  4.800000
# Арбат                                         4.562500
# Аэропорт                                      4.483333
# ...                                                ...
# Южное Тушино                                  4.650000
# Южнопортовый                                  4.500000
# Якиманка                                      4.650000
# Ярославский                                   4.757143
# Ясенево                                       4.260000
#
#                средний_рейтинг_школа_в_районе
# район
# Академический                        4.175000
# Алексеевский                         4.400000
# Алтуфьевский                         4.380000
# Арбат                                4.737500
# Аэропорт                             4.577778
# ...                                       ...
# Южное Тушино                         4.526667
# Южнопортовый                         4.361538
# Якиманка                             4.518182
# Ярославский                          3.488889
# Ясенево                              4.527273
#
# [132 rows x 9 columns]

# %%
gr = gr.reset_index()
gr
# Out:
#              район  средний_рейтинг_бизнес-центр_в_районе  \
# 0    Академический                               4.542857
# 1     Алексеевский                               4.200000
# 2     Алтуфьевский                               4.880000
# 3            Арбат                               4.716667
# 4         Аэропорт                               4.668750
# ..             ...                                    ...
# 127   Южное Тушино                               4.550000
# 128   Южнопортовый                               4.250000
# 129       Якиманка                               4.678571
# 130    Ярославский                               4.700000
# 131        Ясенево                               4.800000
#
#      средний_рейтинг_детский сад_в_районе  средний_рейтинг_кафе_в_районе  \
# 0                                4.314286                       4.244444
# 1                                4.500000                       4.282051
# 2                                4.500000                       3.900000
# 3                                5.000000                       4.151111
# 4                                4.871429                       4.280952
# ..                                    ...                            ...
# 127                              4.320000                       3.955000
# 128                              4.583333                       3.922500
# 129                              5.000000                       4.197959
# 130                              4.611111                       3.995000
# 131                              4.661538                       3.836364
#
#      средний_рейтинг_магазин_в_районе  средний_рейтинг_музей_в_районе  \
# 0                            4.177083                        4.442857
# 1                            4.522000                        4.950000
# 2                            4.348000                             NaN
# 3                            4.314286                        4.760000
# 4                            4.329545                        4.883333
# ..                                ...                             ...
# 127                          4.368889                             NaN
# 128                          4.457447                        5.000000
# 129                          4.408333                        4.582353
# 130                          4.465909                             NaN
# 131                          4.546809                        4.800000
#
#      средний_рейтинг_парк_в_районе  средний_рейтинг_поликлиника_в_районе  \
# 0                         4.000000                              3.475000
# 1                              NaN                              3.166667
# 2                         3.800000                              4.466667
# 3                         4.900000                              4.733333
# 4                         3.960000                              3.642857
# ..                             ...                                   ...
# 127                            NaN                              3.850000
# 128                       4.600000                              4.220000
# 129                       4.866667                              4.400000
# 130                       4.000000                              2.966667
# 131                       4.625000                              3.842857
#
#      средний_рейтинг_торговый центр_в_районе  средний_рейтинг_школа_в_районе
# 0                                   4.350000                        4.175000
# 1                                   4.800000                        4.400000
# 2                                   4.800000                        4.380000
# 3                                   4.562500                        4.737500
# 4                                   4.483333                        4.577778
# ..                                       ...                             ...
# 127                                 4.650000                        4.526667
# 128                                 4.500000                        4.361538
# 129                                 4.650000                        4.518182
# 130                                 4.757143                        3.488889
# 131                                 4.260000                        4.527273
#
# [132 rows x 10 columns]

# %% [markdown]
# Присоединим эти данные к нашей таблице.

# %%
merged = merged.merge(gr, on='район', how='left')

# %%
merged.to_csv('all.csv')

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________
